# %% [markdown]
# # Notebook de prueba

# %% [markdown]
# ## Primer apartado

# %% [markdown]
# Primero lo primero: pylab mode

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x= linspace(x,5)
plot(x, sin(x))

# %%
import numpy as np
import scipy as sp

import matplotlib.pyplot as plt

# %%
#np.linspace?
x= np.linspace(0,5)
plot(x, sin(x))

# %%
print('Hola mundo moviendo celdas')
# Out:
# Hola mundo moviendo celdas
